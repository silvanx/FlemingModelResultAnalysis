# %%
from pathlib import Path
import plot_utils as u

# %%
plot_start_t = 9000
plot_end_t = 12000
steady_state_time = 6000
sim_time = 18000.01

# %%
import matplotlib.pyplot as plt

# %%
# u.plot_mse_dir('PI_grid_search_12')

# %%
from matplotlib import cm
u.plot_fitness_pi_params('PI_grid_search_12', lam=0.4, tail_length=12, three_d=False, recalculate=False, cmap=cm.RdBu_r, fontsize=28)
